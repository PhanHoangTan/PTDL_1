# %% [markdown]
# Tiến hành tải dữ liệu vào chương trình ứng dụng Python và giải quyết vấn đề “Missing
# header in the csv file”

# %%
import pandas as pd
# Id,Name,Age,Weight,m0006,m0612,m1218,f0006,f0612,f1218
colum_name = ['Id', 'Name','Age', 'Weight','m0006','m0612','m1218','f0006','f0612','f1218'] 
df = pd.read_csv('patient_heart_rate.csv', names = colum_name)
df.head(16)
# Out:
#      Id            Name  Age      Weight  m0006  m0612  m1218  f0006  f0612  \
# 0    Id            Name  Age      Weight  m0006  m0612  m1218  f0006  f0612
# 1     1    Mickéy Mousé   56       70kgs     72     69     71      -      -
# 2     2     Donald Duck   34   154.89lbs      -      -      -     85     84
# 3     3      Mini Mouse   16         NaN      -      -      -     65     69
# 4     4  Scrooge McDuck  NaN       78kgs     78     79     72      -      -
# 5     5    Pink Panther   54  198.658lbs      -      -      -     69    NaN
# 6     6     Huey McDuck   52      189lbs      -      -      -     68     75
# 7     7    Dewey McDuck   19       56kgs      -      -      -     71     78
# 8     8      Scööpy Doo   32       78kgs     78     76     75      -      -
# 9   NaN             NaN  NaN         NaN    NaN    NaN    NaN    NaN    NaN
# 10  NaN             NaN  NaN         NaN    NaN    NaN    NaN    NaN    NaN
# 11    9     Huey McDuck   52      189lbs      -      -      -     68     75
# 12   10    Louie McDuck   12       45kgs      -      -      -     92     95
# 13   11       Henry Nam  NaN       60kgs     78     75     72      -      -
# 14   12     Michel Long   34         NaN     65     67     55      -      -
# 15   13      Tana Ricky  NaN         NaN      -      -      -     68     72
#
#     f1218
# 0   f1218
# 1       -
# 2      76
# 3      72
# 4       -
# 5      75
# 6      72
# 7      75
# 8       -
# 9     NaN
# 10    NaN
# 11     72
# 12     87
# 13      -
# 14      -
# 15     70

# %% [markdown]
# Xử lý vấn đề một cột lưu hỗn hợp nhiều dữ liệu, ở đây là cột “Name” chứa bao gồm
# “Firstname” và “Lastname”, giải pháp là ta sẽ tách ra làm 2 cột

# %%
df[['Firstname','Lastname']] = df['Name'].str.split(' ', expand = True)
df = df.drop('Name', axis = 1)
df.head(16)
# Out:
#      Id  Age      Weight  m0006  m0612  m1218  f0006  f0612  f1218 Firstname  \
# 0    Id  Age      Weight  m0006  m0612  m1218  f0006  f0612  f1218      Name
# 1     1   56       70kgs     72     69     71      -      -      -    Mickéy
# 2     2   34   154.89lbs      -      -      -     85     84     76    Donald
# 3     3   16         NaN      -      -      -     65     69     72      Mini
# 4     4  NaN       78kgs     78     79     72      -      -      -   Scrooge
# 5     5   54  198.658lbs      -      -      -     69    NaN     75      Pink
# 6     6   52      189lbs      -      -      -     68     75     72      Huey
# 7     7   19       56kgs      -      -      -     71     78     75     Dewey
# 8     8   32       78kgs     78     76     75      -      -      -    Scööpy
# 9   NaN  NaN         NaN    NaN    NaN    NaN    NaN    NaN    NaN       NaN
# 10  NaN  NaN         NaN    NaN    NaN    NaN    NaN    NaN    NaN       NaN
# 11    9   52      189lbs      -      -      -     68     75     72      Huey
# 12   10   12       45kgs      -      -      -     92     95     87     Louie
# 13   11  NaN       60kgs     78     75     72      -      -      -     Henry
# 14   12   34         NaN     65     67     55      -      -      -    Michel
# 15   13  NaN         NaN      -      -      -     68     72     70      Tana
#
#    Lastname
# 0      None
# 1     Mousé
# 2      Duck
# 3     Mouse
# 4    McDuck
# 5   Panther
# 6    McDuck
# 7    McDuck
# 8       Doo
# 9       NaN
# 10      NaN
# 11   McDuck
# 12   McDuck
# 13      Nam
# 14     Long
# 15    Ricky

# %% [markdown]
# Cột Weight có vấn đề về không thống nhất các đơn vị đo lường trong dữ liệu. Ta sẽ
# chuyển các đơn vị về thành đơn vị chuẩn “kg”

# %%
weight = df['Weight']
for i in range(0,len(weight)):
    x =  str(weight[i])
    if 'lbs' in x[-3:]:
        x = x[:-3:]
        float_x = float(x)
        y = int(float_x/2.2)
        # y = str(y) 
        weight[i] = y
    if 'kgs' in x[-3:]:
        x = x[:-3:]
        float_x = float(x)
        weight[i] = x

df.rename(columns = {'Weight':'Weight_kgs'}, inplace = True)
df.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Weight'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 weight = df['Weight']
#       2 for i in range(0,len(weight)):
#       3     x =  str(weight[i])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'Weight'

# %% [markdown]
# Vấn đề về xuất hiện dòng dữ liệu rỗng (không có giá trị: NaN). Giải pháp có thể đưa ra là
# xóa bỏ

# %%
df.dropna(how='all', inplace=True)

# %% [markdown]
# Có nhiều dòng dữ liệu bị trùng lắp thông tin hoàn toàn[fullname, lastname, age,
# weight_kgs,....], giải pháp đưa ra là chỉ giữ lại một dòng dữ liệu, tuy nhiên giải pháp phải
# dựa trên nghiệp vụ của tập dữ liệu và quan sát của người xử lý.

# %%
df = df.drop_duplicates(subset = ['Firstname', 'Lastname', 'Age', 'Weight_kgs'])

# %% [markdown]
# Xuất hiện dữ liệu bị ảnh hưởng bởi lỗi non-ASCII, không định dạng ASCII. Giải pháp:
# Tùy vào nghiệp vụ ta có thể: xóa dữ liệu tại đó, thay thế bằng dữ liệu khác hoặc thay
# bằng việc đánh dấu bằng một kí tự khác (ví dụ: ‘warning’)

# %%
df.Firstname.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
df.Lastname.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
print(df)
# Out:
#     Id  Age Weight_kgs  m0006  m0612  m1218  f0006  f0612  f1218 Firstname  \
# 0   Id  Age     Weight  m0006  m0612  m1218  f0006  f0612  f1218      Name
# 1    1   56         70     72     69     71      -      -      -     Micky
# 2    2   34         70      -      -      -     85     84     76    Donald
# 3    3   16        NaN      -      -      -     65     69     72      Mini
# 4    4  NaN         78     78     79     72      -      -      -   Scrooge
# 5    5   54         90      -      -      -     69    NaN     75      Pink
# 6    6   52         85      -      -      -     68     75     72      Huey
# 7    7   19         56      -      -      -     71     78     75     Dewey
# 8    8   32         78     78     76     75      -      -      -      Scpy
# 12  10   12         45      -      -      -     92     95     87     Louie
# 13  11  NaN         60     78     75     72      -      -      -     Henry
# 14  12   34        NaN     65     67     55      -      -      -    Michel
# 15  13  NaN        NaN      -      -      -     68     72     70      Tana
# 16  14  NaN        NaN    NaN    NaN    NaN    NaN    NaN    NaN  UniLever
# 17  15   52         81      -      -      -     68     75     72       NaN
#
#    Lastname
# 0      None
# 1      Mous
# 2      Duck
# 3     Mouse
# 4    McDuck
# 5   Panther
# 6    McDuck
# 7    McDuck
# 8       Doo
# 12   McDuck
# 13      Nam
# 14     Long
# 15    Ricky
# 16     None
# 17      NaN
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13420\3758458077.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Firstname.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13420\3758458077.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.Lastname.replace({r'[^\x00-\x7F]+':''}, regex=True, inplace=True)

# %% [markdown]
# “Missing values”, vấn đề này xảy ra tại các cột “Age”, “Weight” và “Heart Rate”. Thiếu
# dữ liệu (dữ liệu không đầy đủ) là vấn đề xảy ra nhiều trong các nguồn dữ liệu do nhiều
# nguyên nhân chủ quan lẫn khách quan. Có một vài giải pháp để xử lý vấn đề này, chủ yếu
# dựa trên kinh nghiệm và nghiệp vụ về tập dữ liệu đó. Một số giải pháp đưa đề xuất từ
# chuyên gia như sau:
# a. Deletion: Remove records with missing values
# b. Dummy substitution: Replace missing values with a dummy but valid
# value: e.g.: 0 for numerical values.
# c. Mean substitution: Replace the missing values with the mean.
# d. Frequent substitution: Replace the missing values with the most
# frequent item.
# e. Improve the data collector: Your business folk will talk to the clients
# and inform them about why it is worth fixing the problem with the data
# collector.
# Thay giá trị thiếu của tuổi bằng giá trị yếu vị.

# %%
df['Age'].fillna(df['Age'].mode()[0], inplace = True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13420\1370003872.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Age'].fillna(df['Age'].mode()[0], inplace = True)

# %% [markdown]
# Thay giá trị thiếu của cân nặng bằng giá trị trung vị

# %%
df['Weight_kgs'].fillna(df['Weight_kgs'].mode()[0], inplace = True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_13420\3297879392.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Weight_kgs'].fillna(df['Weight_kgs'].mode()[0], inplace = True)

# %% [markdown]
#  “Một cột chứa quá nhiều thông tin cần được phân rã”, như trong bài toán này ta thấy
# header “m0006” chứa các nội dung bao gồm: m → male, 0006 ~ 00-06 (lần đo chỉ số
# huyết áp từ 00h- đến 06h). Còn giá trị thì là kết quả huyết áp.

# %%
df = pd.melt(df, id_vars = ['Id', 'Age', 'Weight_kgs', 'Firstname', 'Lastname'], value_name='PulseRate', var_name='gender_time').sort_values(['Id','Age','Weight_kgs','Firstname','Lastname'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 df = pd.melt(df, id_vars = ['Id', 'Age', 'Weight_kgs', 'Firstname', 'Lastname'], value_name='PulseRate', var_name='gender_time').sort_values(['Id','Age','Weight_kgs','Firstname','Lastname'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\reshape\melt.py:52, in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      49     cols = list(frame.columns)
#      51 if value_name in frame.columns:
# ---> 52     raise ValueError(
#      53         f"value_name ({value_name}) cannot match an element in "
#      54         "the DataFrame columns."
#      55     )
#      57 if id_vars is not None:
#      58     if not is_list_like(id_vars):
#
# ValueError: value_name (PulseRate) cannot match an element in the DataFrame columns.

# %% [markdown]
# Tạo data frame tạm là kết quả của việc tách cột gender_time

# %%
df_temp = df['gender_time'].str.extract('(\D)(\d+)(\d{2})',expand=True)
df_temp.columns
# Out:
# Index([0, 1, 2], dtype='int64')

# %% [markdown]
# Đặt tên cột cho data frame tạm

# %%
df_temp.columns = ['Gender', 'Lower_hour', 'Upper_hour']

# %% [markdown]
# Nối data frame tạm vào data frame ban đầu

# %%
df = pd.concat([df, df_temp], axis = 1)

# %% [markdown]
# Bỏ cột gender_time

# %%
df = df.drop(['gender_time'], axis = 1)

# %% [markdown]
# Loại bỏ hết các dòng dữ liệu thừa là những dòng có phần PulseRate có dấu -

# %%
import numpy as np
df = df.replace('-', np.nan).dropna(subset=['PulseRate'])
df.head(5)
# Out:
#     Id Age Weight_kgs Firstname Lastname PulseRate Gender Lower_hour  \
# 1    1  56         70     Micky     Mous        72      m         00
# 16   1  56         70     Micky     Mous        69      m         06
# 31   1  56         70     Micky     Mous        71      m         12
# 54  10  12         45     Louie   McDuck        92      f         00
# 69  10  12         45     Louie   McDuck        95      f         06
#
#    Upper_hour
# 1          06
# 16         12
# 31         18
# 54         06
# 69         12

# %% [markdown]
#  Nhận thấy có những bệnh nhân chưa ghi nhận họ tên (ví lý do nào đó)

# %%
df['Firstname'].isnull().sum()
df['Lastname'].isnull().sum()
df['Firstname'].fillna('Unknown', inplace = True)
df['Lastname'].fillna('Unknown', inplace = True)

# %% [markdown]
# Sau khi xử lý thì index của dòng dữ liệu đã thay đổi lung tung, ta cần reset index lại cho
# theo khuôn mẫu

# %%
df = df.reset_index()

# %% [markdown]
#  Sau đó, lưu trữ dữ liệu đã xử lý thành công với tên file patient_heart_rate_clean.csv

# %%
df.to_csv('patient_heart_rate_clean.csv')
