# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import random

# 1 Doc file du lieu
df = pd.read_csv('orginal_sales_data_edit.csv')
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
# 3.doc file voi cac tuy chon mac dinh. hieu thi 5 dong du lieu dau tien
df = pd .read_csv('orginal_sales_data_edit.csv')
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 0            NYC    NY      10022     USA       NaN              Yu
# ...

# %%
#4. doc file voi cac tuy chon mac dinh. hien thi 5 dong du lieu cuoi cung
df.tail(5)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 2818  12/2/2004   Shipped       4        12     2004  ...          NaN
# 2819  1/31/2005   Shipped       1         1     2005  ...          NaN
# 2820   3/1/2005  Resolved       1         3     2005  ...          NaN
# 2821  3/28/2005   Shipped       1         3     2005  ...          NaN
# 2822   5/6/2005   On Hold       2         5     2005  ...          NaN
#
#           CITY STATE POSTALCODE  COUNTRY TERRITORY CONTACTLASTNAME  \
# ...

# %%
#5.Chuyen kieu du lieu cho 1 cot nao do
df["YEAR_ID"] = df["YEAR_ID"].astype("int32")
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 0            NYC    NY      10022     USA       NaN              Yu
# ...

# %%
#6.Xem chieu dai cua df, tuong duong shape[0]
print("Chieu dai cua df: ", len(df))
# Out:
# Chieu dai cua df:  2823

# %%
#7.Xem thong tin dataframe vua doc duoc
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int32
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CATEGORY          2823 non-null   object
#  14  SUBCATEGORY       2823 non-null   object
#  15  CUSTOMERNAME      2823 non-null   object
# ...

# %%
#8. Xem kich thuoc cua dataframe
print("Kich thuoc cua df: ", df.shape)
# Out:
# Kich thuoc cua df:  (2823, 28)

# %%
#9. Hieu thi du lieu cua cot thu 10
df.iloc[:, 10]
df['PRODUCTLINE']
# Out:
# 0       Motorcycles
# 1       Motorcycles
# 2       Motorcycles
# 3       Motorcycles
# 4       Motorcycles
#            ...
# 2818          Ships
# 2819          Ships
# 2820          Ships
# 2821          Ships
# 2822          Ships
# Name: PRODUCTLINE, Length: 2823, dtype: object

# %%
#10. Hieu thi du lieu cua cot 1,2,3,5,6
df.iloc[:, [1, 2, 3, 5, 6]]
# Out:
#       QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   ORDERDATE    STATUS
# 0                  30      95.70                2   2/24/2003   Shipped
# 1                  34      81.35                5    5/7/2003   Shipped
# 2                  41      94.74                2    7/1/2003   Shipped
# 3                  45      83.26                6   8/25/2003   Shipped
# 4                  49     100.00               14  10/10/2003   Shipped
# ...               ...        ...              ...         ...       ...
# 2818               20     100.00               15   12/2/2004   Shipped
# 2819               29     100.00                1   1/31/2005   Shipped
# 2820               43     100.00                4    3/1/2005  Resolved
# 2821               34      62.24                1   3/28/2005   Shipped
# 2822               47      65.52                9    5/6/2005   On Hold
#
# [2823 rows x 5 columns]

# %%
#11. Hieu thi 5 dong du lieu dau tien gom cac cot 1,2,3,5,6
df.iloc[0:5, [1, 2, 3, 5, 6]]
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   ORDERDATE   STATUS
# 0               30      95.70                2   2/24/2003  Shipped
# 1               34      81.35                5    5/7/2003  Shipped
# 2               41      94.74                2    7/1/2003  Shipped
# 3               45      83.26                6   8/25/2003  Shipped
# 4               49     100.00               14  10/10/2003  Shipped

# %%
#12.Hieu thi 5 dong du lieu dau tien theo chi so 
df[0:5]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 0            NYC    NY      10022     USA       NaN              Yu
# ...

# %%
#13.Hieu thi 5 dong du lieu dau tien theo chi so gom cac cot 1,2,3,5,6
df.iloc[:5, [1, 2, 3, 5, 6]]
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   ORDERDATE   STATUS
# 0               30      95.70                2   2/24/2003  Shipped
# 1               34      81.35                5    5/7/2003  Shipped
# 2               41      94.74                2    7/1/2003  Shipped
# 3               45      83.26                6   8/25/2003  Shipped
# 4               49     100.00               14  10/10/2003  Shipped

# %%
#14.loai bo cac dong trung nhau
df.drop_duplicates(inplace=True)
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
#15.Loai bo cac dong trong co du lieu cua 1 cot la trong, co 2823 dong
df["ADDRESSLINE2"].isna().sum()
# Out:
# 2521

# %%
#16.Loai bo cac dong khong biet cua 1 cot co gia tri la unknown,
df["ADDRESSLINE2"].fillna("Unknown", inplace=True)
df["ADDRESSLINE2"].isna().sum()
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
#17. Lay du lieu cua 1 cot theo dang chuoi 
df["QUANTITYORDERED"]
# Out:
# 0       30
# 1       34
# 2       41
# 3       45
# 4       49
#         ..
# 2818    20
# 2819    29
# 2820    43
# 2821    34
# 2822    47
# Name: QUANTITYORDERED, Length: 2823, dtype: int64

# %%
#18. Lay du lieu cua 1 cot ve mot mang 
df["QUANTITYORDERED"].values
# Out:
# array([30, 34, 41, ..., 43, 34, 47], dtype=int64)

# %%
#19. Lay du tu dong so 4 den dong 9
df[4:10]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
# 9        10211               41     100.00               14  4708.44
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 4  10/10/2003  Shipped       4        10     2003  ...      Unknown
# 5  10/28/2003  Shipped       4        10     2003  ...      Unknown
# 6  11/11/2003  Shipped       4        11     2003  ...      Unknown
# 7  11/18/2003  Shipped       4        11     2003  ...      Unknown
# 8   12/1/2003  Shipped       4        12     2003  ...      Unknown
# 9   1/15/2004  Shipped       1         1     2004  ...      Unknown
#
# ...

# %%
#21.Doc du lieu tu dong 4 den dong 9
df.iloc[4:10]
df.loc[4:10]
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 4         10159               49     100.00               14  5205.27
# 5         10168               36      96.66                1  3479.76
# 6         10180               29      86.13                9  2497.77
# 7         10188               48     100.00                1  5512.32
# 8         10201               22      98.57                2  2168.54
# 9         10211               41     100.00               14  4708.44
# 10        10223               37     100.00                1  3965.66
#
#      ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 4   10/10/2003  Shipped       4        10     2003  ...      Unknown
# 5   10/28/2003  Shipped       4        10     2003  ...      Unknown
# 6   11/11/2003  Shipped       4        11     2003  ...      Unknown
# 7   11/18/2003  Shipped       4        11     2003  ...      Unknown
# ...

# %%
#22.Lay thong tin tai dong co chi so la 2
df.iloc[2]
# Out:
# ORDERNUMBER                                 10134
# QUANTITYORDERED                                41
# PRICEEACH                                   94.74
# ORDERLINENUMBER                                 2
# SALES                                     3884.34
# ORDERDATE                                7/1/2003
# STATUS                                    Shipped
# QTR_ID                                          3
# MONTH_ID                                        7
# YEAR_ID                                      2003
# PRODUCTLINE                           Motorcycles
# MSRP                                           95
# PRODUCTCODE                              S10_1678
# CATEGORY                                Furniture
# SUBCATEGORY                               Cabinet
# CUSTOMERNAME                      Lyon Souveniers
# PHONE                            +33 1 46 62 7555
# ADDRESSLINE1        27 rue du Colonel Pierre Avia
# ADDRESSLINE2                              Unknown
# ...

# %%
#23.Lay thong tin tu dong4 den dong 10 cua mot so cot
df.iloc[4:10, [1, 2, 3, 5, 6]]
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   ORDERDATE   STATUS
# 4               49     100.00               14  10/10/2003  Shipped
# 5               36      96.66                1  10/28/2003  Shipped
# 6               29      86.13                9  11/11/2003  Shipped
# 7               48     100.00                1  11/18/2003  Shipped
# 8               22      98.57                2   12/1/2003  Shipped
# 9               41     100.00               14   1/15/2004  Shipped

# %%
#24. Lay thong tin tu dong so 2 den dong 9, tu cot 4 den cot 7
df.iloc[2:9, 4:7]
# Out:
#      SALES   ORDERDATE   STATUS
# 2  3884.34    7/1/2003  Shipped
# 3  3746.70   8/25/2003  Shipped
# 4  5205.27  10/10/2003  Shipped
# 5  3479.76  10/28/2003  Shipped
# 6  2497.77  11/11/2003  Shipped
# 7  5512.32  11/18/2003  Shipped
# 8  2168.54   12/1/2003  Shipped

# %%
#25.Lay du lieu tai chi so la 2
df.iloc[2]
# Out:
# ORDERNUMBER                                 10134
# QUANTITYORDERED                                41
# PRICEEACH                                   94.74
# ORDERLINENUMBER                                 2
# SALES                                     3884.34
# ORDERDATE                                7/1/2003
# STATUS                                    Shipped
# QTR_ID                                          3
# MONTH_ID                                        7
# YEAR_ID                                      2003
# PRODUCTLINE                           Motorcycles
# MSRP                                           95
# PRODUCTCODE                              S10_1678
# CATEGORY                                Furniture
# SUBCATEGORY                               Cabinet
# CUSTOMERNAME                      Lyon Souveniers
# PHONE                            +33 1 46 62 7555
# ADDRESSLINE1        27 rue du Colonel Pierre Avia
# ADDRESSLINE2                              Unknown
# ...

# %%
#26. Lay du lieu tu dong dau tien den dong 9 dung iloc
df.iloc[0:9]
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
# 5        10168               36      96.66                1  3479.76
# 6        10180               29      86.13                9  2497.77
# 7        10188               48     100.00                1  5512.32
# 8        10201               22      98.57                2  2168.54
#
#     ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003  Shipped       1         2     2003  ...      Unknown
# 1    5/7/2003  Shipped       2         5     2003  ...      Unknown
# 2    7/1/2003  Shipped       3         7     2003  ...      Unknown
# ...

# %%
#27.Lay du lieu tu dong dau tien den dong 9 dung iloc gom cac cot 4 den 7 
df.iloc[0:9, 4:7]
# Out:
#      SALES   ORDERDATE   STATUS
# 0  2871.00   2/24/2003  Shipped
# 1  2765.90    5/7/2003  Shipped
# 2  3884.34    7/1/2003  Shipped
# 3  3746.70   8/25/2003  Shipped
# 4  5205.27  10/10/2003  Shipped
# 5  3479.76  10/28/2003  Shipped
# 6  2497.77  11/11/2003  Shipped
# 7  5512.32  11/18/2003  Shipped
# 8  2168.54   12/1/2003  Shipped

# %%
#28.Sap xep du lieu theo Sales tang dan
df.sort_values(by="SALES",ascending=True)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 2249        10425               11      43.83                6    482.13
# 1287        10407                6      90.19                3    541.14
# 2044        10408               15      36.93                1    553.95
# 1551        10280               20      28.88               12    577.60
# 1818        10419               15      42.67                7    640.05
# ...           ...              ...        ...              ...       ...
# 104         10403               66     100.00                9  11886.60
# 1062        10412               60     100.00                9  11887.80
# 53          10424               50     100.00                6  12001.00
# 744         10322               50     100.00                6  12536.50
# 598         10407               76     100.00                2  14082.80
#
#       ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
#29.Sap xep du lieu theo nhieu tieu chi
df.sort_values(by=["SALES", "QUANTITYORDERED"], ascending=[True, False])
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 2249        10425               11      43.83                6    482.13
# 1287        10407                6      90.19                3    541.14
# 2044        10408               15      36.93                1    553.95
# 1551        10280               20      28.88               12    577.60
# 1818        10419               15      42.67                7    640.05
# ...           ...              ...        ...              ...       ...
# 104         10403               66     100.00                9  11886.60
# 1062        10412               60     100.00                9  11887.80
# 53          10424               50     100.00                6  12001.00
# 744         10322               50     100.00                6  12536.50
# 598         10407               76     100.00                2  14082.80
#
#       ORDERDATE      STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %%
#30.Loc du lieu theo 1 dieu kien 
df[df["SALES"] > 10000]
print('Cach 2')
df.loc[df["SALES"] > 10000]
# Out:
# Cach 2
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 30          10150               45      100.0                8  10993.5
# 43          10304               47      100.0                6  10172.7
# 44          10312               48      100.0                3  11623.7
# 53          10424               50      100.0                6  12001.0
# 104         10403               66      100.0                9  11886.6
# 188         10127               46      100.0                2  11279.2
# 198         10247               44      100.0                2  10606.2
# 598         10407               76      100.0                2  14082.8
# 744         10322               50      100.0                6  12536.5
# 1062        10412               60      100.0                9  11887.8
# 1133        10333               46      100.0                2  11336.7
# 1188        10406               65      100.0                1  10468.9
# ...

# %%
#31.Loc du lieu theo nhieu dieu kien 
df[(df["SALES"] > 10000) & (df["QUANTITYORDERED"] > 50)]
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 104         10403               66      100.0                9  11886.6
# 598         10407               76      100.0                2  14082.8
# 1062        10412               60      100.0                9  11887.8
# 1188        10406               65      100.0                1  10468.9
# 1839        10339               55      100.0               13  10758.0
# 1995        10405               76      100.0                3  11739.7
#
#        ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 104     4/8/2005   Shipped       2         4     2005  ...          NaN
# 598    4/22/2005   On Hold       2         4     2005  ...          NaN
# 1062    5/3/2005   Shipped       2         5     2005  ...          NaN
# 1188   4/15/2005  Disputed       2         4     2005  ...          NaN
# 1839  11/23/2004   Shipped       4        11     2004  ...          NaN
# ...

# %%
#32.Loc gia tri va gan dieu kien dung loc
df.loc[df["PRICEEACH"] > 65, "FLAG"] = "EXPENSIVE"

# %%
#33.Viet ham tra ve gia tri co nhieu dieu kien va ap dung ham gan gia tri tra ve 1 cot 
def foo(x):
    if x <10:
        return "BAD"
    elif x>=10 and x<50:
        return "GOOD"
    else:
        return "EXCELLENT"
df["WORTH"] = df[['QUANTITYORDERED']].applymap(foo)
df[['QUANTITYORDERED', 'WORTH']]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20628\1862421241.py:9: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df["WORTH"] = df[['QUANTITYORDERED']].applymap(foo)
#       QUANTITYORDERED WORTH
# 0                  30  GOOD
# 1                  34  GOOD
# 2                  41  GOOD
# 3                  45  GOOD
# 4                  49  GOOD
# ...               ...   ...
# 2818               20  GOOD
# 2819               29  GOOD
# 2820               43  GOOD
# 2821               34  GOOD
# 2822               47  GOOD
#
# [2823 rows x 2 columns]

# %%
#34.Anh xa gia tri toi 1cot
dict_map = {1: "Qui_1", 2: "Qui_2", 3: "Qui_3", 4: "Qui_4"}
df['QTR_ID']=df["QTR_ID"].map(dict_map)
df['QTR_ID']
# Out:
# 0       Qui_1
# 1       Qui_2
# 2       Qui_3
# 3       Qui_3
# 4       Qui_4
#         ...
# 2818    Qui_4
# 2819    Qui_1
# 2820    Qui_1
# 2821    Qui_1
# 2822    Qui_2
# Name: QTR_ID, Length: 2823, dtype: object

# %%
#35.Lay nhung dong du lieu bang 1 dieu kien nao do
df[['QUANTITYORDERED', 'PRICEEACH']].loc[df['QUANTITYORDERED'] > 50]
# Out:
#       QUANTITYORDERED  PRICEEACH
# 25                 66     100.00
# 104                66     100.00
# 105                56     100.00
# 131                64     100.00
# 260                55     100.00
# 264                66     100.00
# 392                54     100.00
# 414                55      75.20
# 418                97      93.28
# 447                54     100.00
# 473                61     100.00
# 500                51      95.55
# 550                59     100.00
# 598                76     100.00
# 620                55      65.45
# 624                61      73.92
# 726                56      98.18
# 828                55      55.72
# 880                55     100.00
# 1061               55     100.00
# 1062               60     100.00
# 1160               55     100.00
# 1188               65     100.00
# 1239               58     100.00
# 1240               51     100.00
# 1288               66      92.95
# 1413               66      66.99
# ...

# %%
#36. Hieu thi du cac ban ghi co so luong hon 25
df.loc[df['QUANTITYORDERED'] > 25]
print("Hieu thi 5 dong du lieu dau tien")
Tuoitre = df.loc[df['QUANTITYORDERED'] > 25]
Tuoitre.head(5)
# Out:
# Hieu thi 5 dong du lieu dau tien
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#     ORDERDATE   STATUS QTR_ID  MONTH_ID  YEAR_ID  ... STATE  POSTALCODE  \
# 0   2/24/2003  Shipped  Qui_1         2     2003  ...    NY       10022
# 1    5/7/2003  Shipped  Qui_2         5     2003  ...   NaN       51100
# 2    7/1/2003  Shipped  Qui_3         7     2003  ...   NaN       75508
# 3   8/25/2003  Shipped  Qui_3         8     2003  ...    CA       90003
# 4  10/10/2003  Shipped  Qui_4        10     2003  ...    CA         NaN
#
#   COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE PAYMENTFULLNAME  \
# ...

# %%
#37.Hieu thi cac hoa don da duoc giao
df.loc[df['STATUS'] == 'Shipped']
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2815        10315               40      55.69                5  2227.60
# 2817        10337               42      97.16                5  4080.72
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2821        10397               34      62.24                1  2116.16
#
#        ORDERDATE   STATUS QTR_ID  MONTH_ID  YEAR_ID  ... STATE  POSTALCODE  \
# ...

# %%
#37.Sp sanh chuoi 
sosanh = df['STATUS'].str.contains('Shipped')
sosanh.head(5)
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: STATUS, dtype: bool

# %%
#38.LAy gia tri tra ve mang
df['STATUS'].values
# Out:
# array(['Shipped', 'Shipped', 'Shipped', ..., 'Resolved', 'Shipped',
#        'On Hold'], dtype=object)

# %%
#40.Them 1 cot vao file du lieu
df_len = len(df)
ngaylap = [random.randrange(2003,2005,1) for i in range(df_len)]
df["ORDERDATE"] = ngaylap
df.tail(5)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS QTR_ID  MONTH_ID  YEAR_ID  ... STATE  POSTALCODE  \
# 2818       2004   Shipped  Qui_4        12     2004  ...   NaN       28034
# 2819       2003   Shipped  Qui_1         1     2005  ...   NaN       90110
# 2820       2004  Resolved  Qui_1         3     2005  ...   NaN       28034
# 2821       2003   Shipped  Qui_1         3     2005  ...   NaN       31000
# 2822       2003   On Hold  Qui_2         5     2005  ...    MA       51003
#
#       COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE  \
# ...

# %%
#41. Them 1 cot vao (Dagiao) vao du lieu theo tieu chi neu dieu kien thoa thi dac gia tri mac dinh la True 
df['DaGiao'] = df['STATUS'].str.contains('Shipped')
df.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS QTR_ID  MONTH_ID  YEAR_ID  ... POSTALCODE  COUNTRY  \
# 0       2003  Shipped  Qui_1         2     2003  ...      10022      USA
# 1       2003  Shipped  Qui_2         5     2003  ...      51100   France
# 2       2004  Shipped  Qui_3         7     2003  ...      75508   France
# 3       2004  Shipped  Qui_3         8     2003  ...      90003      USA
# 4       2003  Shipped  Qui_4        10     2003  ...        NaN      USA
#
#   TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE PAYMENTFULLNAME  \
# ...

# %%
#42. Tsao 1 cot moi co gia tri rong
df['TongTien'] = None
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS QTR_ID  MONTH_ID  YEAR_ID  ...  COUNTRY  TERRITORY  \
# ...

# %%
#44.Sua gia tri cua cot
df["QTR_ID"]=None
df["QTR_ID"]="Quy"
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS QTR_ID  MONTH_ID  YEAR_ID  ...  COUNTRY  TERRITORY  \
# ...

# %%
#45.Xoa cot trong dataframe
df.drop("QTR_ID", axis=1, inplace=True)

# %%
#46.Xoa ban ghi thoe chi so
df.drop([0,1])
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# 5           10168               36      96.66                1  3479.76
# 6           10180               29      86.13                9  2497.77
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#       ORDERDATE    STATUS  MONTH_ID  YEAR_ID  PRODUCTLINE  ...  COUNTRY  \
# ...

# %%
#47.Su dung ham describe de xem thong ke du lieu
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES    ORDERDATE     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3546.280322  2003.480694     7.092455  2003.81509   100.715551
# std     1810.568153     0.499716     3.656633     0.69967    40.187912
# min      482.130000  2003.000000     1.000000  2003.00000    33.000000
# ...

# %%
#48.Xem thong ke tung cot
df['SALES'].value_counts()
# Out:
# SALES
# 10000.00    16
# 3003.00      3
# 7310.00      2
# 7381.16      2
# 7182.00      2
#             ..
# 3441.37      1
# 2023.28      1
# 2245.20      1
# 3255.12      1
# 2116.16      1
# Name: count, Length: 2748, dtype: int64

# %%
#49.Ve do thi phan bo gia tri cua 1 trong trong dataframe
df['SALES'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='SALES'>

# %%
#50.Tao moi dataframe tu cac pythonlist
people = {'name ':{'first':'Hoang', 'last':'Nguyen' }, 'age': 25, 'job': 'AI'}
df_people = pd.DataFrame(people)
df_people
# Out:
#         name   age job
# first   Hoang   25  AI
# last   Nguyen   25  AI

# %%
#51. Sap xep dataframe tang dan theo cot
df1 = pd.DataFrame({'A': [1, 2, 3, 4, 5], 'B': [5, 4, 3, 2, 1]})
df1.sort_values(by='A')
# Out:
#    A  B
# 0  1  5
# 1  2  4
# 2  3  3
# 3  4  2
# 4  5  1

# %%
#52.NOi 2 dataframe
df1 = pd.DataFrame({'A': [1, 2, 3, 4, 5], 'B': [5, 4, 3, 2, 1]})
df2 = pd.DataFrame({'A': [12, 42, 33, 24, 51], 'B': [55, 47, 39, 28, 71]})
df3 = pd.concat([df1, df2])

# %%
#53. Xao tron cac ban ghi trong dataframe
df1 = pd.DataFrame({'A': [1, 2, 3, 4, 5], 'B': [5, 4, 3, 2, 1]})
df1 = df1.sample(frac=1).reset_index(drop=True)

# %%
#54.LUU dataframe vao file csv
df1.to_csv('BangSo.csv')

# %%
#55.Toi uu bo nho khi dung pandas
import numpy as np
import pandas as pd
def reduce_mem_usage(df):
    start_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage of dataframe is {:.2f} MB'.format(start_mem))
    for col in df.columns:
        col_type = df[col].dtype
        if col_type != object:
            c_min = df[col].min()
            c_max = df[col].max()
            if str(col_type)[:3] == 'int':
                if c_min > np.iinfo(np.int8).min and c_max < np.iinfo(np.int8).max:
                    df[col] = df[col].astype(np.int8)
                elif c_min > np.iinfo(np.int16).min and c_max < np.iinfo(np.int16).max:
                    df[col] = df[col].astype(np.int16)
                elif c_min > np.iinfo(np.int32).min and c_max < np.iinfo(np.int32).max:
                    df[col] = df[col].astype(np.int32)
                elif c_min > np.iinfo(np.int64).min and c_max < np.iinfo(np.int64).max:
                    df[col] = df[col].astype(np.int64)
            else:
                if c_min > np.finfo(np.float16).min and c_max < np.finfo(np.float16).max:
                    df[col] = df[col].astype(np.float16)
                elif c_min > np.finfo(np.float32).min and c_max < np.finfo(np.float32).max:
                    df[col] = df[col].astype(np.float32)
                else:
                    df[col] = df[col].astype(np.float64)
    end_mem = df.memory_usage().sum() / 1024**2
    print('Memory usage after optimization is: {:.2f} MB'.format(end_mem))
    print('Decreased by {:.1f}%'.format(100 * (start_mem - end_mem) / start_mem))
    return df
