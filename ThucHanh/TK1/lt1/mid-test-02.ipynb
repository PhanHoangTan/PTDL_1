# %% [markdown]
# <a href="https://colab.research.google.com/github/cu2021/Students_grade_forcasting/blob/master/Students_grade_forcasting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Đây là dữ liệu về thành tích học tập của học sinh trung học tại hai trường học ở Bồ Đào Nha. Các thông tin dữ liệu bao gồm điểm số của học sinh, thông tin dân số học, xã hội và liên quan đến trường học, và dữ liệu này được thu thập thông qua báo cáo của trường và bảng câu hỏi.
#
# Ta cần phân tích xem điểm (G1, G2, G3) có mối quan hệ như thế nào với các thông tin khác.
#
# G1 - điểm kỳ 1 (số: từ 0 đến 20).
# G2 - điểm kỳ 2 (số: từ 0 đến 20).
# G3 - điểm cuối kỳ (số: từ 0 đến 20).

# %% [markdown]
# ## **Import thư viện**

# %% [markdown]
# ## **Tiền xử lý dữ liệu (3.5đ)**

# %% [markdown]
# ### Load dữ liệu (0.5đ)
# * Chỉ giữ lại các cột: school, sex, age, studytime, G1, G2, G3.

# %% [markdown]
# ### Hãy cho biết dữ liệu có bao nhiêu cột và bao nhiêu dòng (0.5đ)

# %% [markdown]
# ### Hiển thị 5 dòng cuối cùng (0.5đ)

# %% [markdown]
# ### Hãy kiểm tra dữ liệu rỗng và xử lý (0.5đ)

# %% [markdown]
# ### Hiển thị kiểu dữ liệu của các cột (0.5đ)

# %% [markdown]
# ### Hãy cho biết các cột là dữ liệu định lượng (0.5đ)

# %% [markdown]
# ### Cho biết các số liệu thống kê cơ bản với các dữ liệu định tính (0.5đ)

# %% [markdown]
# ## **EDA (0.5đ)**
# Với mỗi thao tác, bạn hãy ***nhận xét*** kết quả nhận được.

# %% [markdown]
# ### Vẽ histogram cho G2 và G3 (1đ)

# %% [markdown]
# **Nhận xét**:

# %% [markdown]
# ### Phân tích xem giới tính có ảnh hưởng đến điểm không (1.5đ)

# %% [markdown]
# #### Vẽ biểu đồ tròn thể hiện tỉ lệ giới tính.
#
# * Mã màu: '#ff9999', '#66b3ff'
# * Biểu đồ cần có tiêu đề

# %% [markdown]
# #### Vẽ biểu đồ để so sánh điểm G3 của nam và nữ.

# %% [markdown]
# #### **Nhận xét**

# %% [markdown]
# ### Vẽ biểu đồ nhiệt thể hiện sự tương quan của các biến định lượng (1đ)

# %% [markdown]
# #### **Nhận xét**

# %% [markdown]
# ### Phân tích mối quan hệ giữa số giờ học và điểm (1.5đ)

# %% [markdown]
# #### **Nhận xét**

# %% [markdown]
# ### Xóa các dòng có điểm G3 = 0 (0.5đ)

# %% [markdown]
# ## **Kết luận và các hướng phân tích khác (1đ)**

# %% [markdown]
# Kết luận:
#
# Hướng phân tích khác:

# %% [markdown]
# ## Tự đánh giá
# Bạn đánh giá mình được bao nhiêu điểm?
