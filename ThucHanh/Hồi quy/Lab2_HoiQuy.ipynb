# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dulieuxettuyendaihoc.csv', header=0)
df.head()
# Out:
#     MSSV   T1   T2   T3   T4   T5   T6 GT  DT   KV  NGONNGU  \
# 0  SV001  7.2  8.4  7.4  7.2  7.4  6.9  F NaN  2NT     3.25
# 1  SV002  5.4  6.3  4.3  4.9  3.0  4.0  M NaN    1     6.00
# 2  SV003  5.6  5.0  2.8  6.1  4.8  5.7  M NaN    1     5.00
# 3  SV004  6.6  5.1  5.9  4.1  6.1  7.4  M NaN    1     4.25
# 4  SV005  6.0  5.4  7.6  4.4  6.8  8.0  M NaN  2NT     4.25
#
#    TOANLOGICPHANTICH  GIAIQUYETVANDE  KT    NGAYTHI DINHHUONGNGHENGHIEP
# 0               3.25            4.50  A1  12/7/2018                  No
# 1               4.00            3.50   C  12/7/2018                 Yes
# 2               6.75            4.00   C  12/7/2018                  No
# 3               4.25            5.25  D1  12/7/2018                  No
# 4               4.50            5.00   A  12/7/2018                  No

# %%
''' 
Phân tích hồi quy tuyến tính 
Mục đích: Phân tích tác động hay ảnh hưởng giữa các yếu tố đến mục tiêu (thường đùng 
cho các biến (yếu tố) định lượng) 
Thường vẽ biểu đồ Scatter để khám phá mối tương quan tuyến tính trước khi khám phá 
quan hệ hồi quy tuyến tính 
PHƯƠNG PHÁP 
1. Xác định biến độc lập (yếu tố) và biến phụ thuộc (mục tiêu) 
2. Ghi ra phương trình hồi quy tuyến tính tổng quát y = f(x) 
3. Chạy dữ liệu mô hình 
4. Đọc các giá trị quan trọng và kết luận 
5. Dự báo giá trị biến phụ thuộc khi biết trước giá trị biến độc lập 
'''

# %%
# Hãy cho biết sự ảnh hưởng của điểm học kì 1 năm lớp 12 đến điểm học kì 2 năm lớp 12 
#import statsmodels.api as sm 
#pip install statsmodels –cài đặt thư viện này để sử dụng thư viện #statsmadels.api 
import statsmodels.api as sm 
#linear regression 
''' 
1.  Biến độc lập: học kì 1 (T5) 
    Biến phụ thuộc : học kì 2 (T6) 
2. T6 = f(T5) 
      = Ao + A1*T5 + epsilon 
3. Chạy mô hình 
4. Đọc và hiểu kết quả 
''' 
# adding a constant
X_with_constant = sm.add_constant(df[["T5"]].values) 
y = df[['T6']].values 
# performing the regression 
result = sm.OLS(y,X_with_constant).fit() 
# Result of statsmodels 
print(result.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.602
# Method:                 Least Squares   F-statistic:                     151.0
# Date:                Mon, 07 Oct 2024   Prob (F-statistic):           1.48e-21
# Time:                        00:55:45   Log-Likelihood:                -125.76
# No. Observations:                 100   AIC:                             255.5
# Df Residuals:                      98   BIC:                             260.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.1130      0.402      5.257      0.000       1.315       2.911
# x1             0.7182      0.058     12.286      0.000       0.602       0.834
# ==============================================================================
# Omnibus:                        1.387   Durbin-Watson:                   1.738
# Prob(Omnibus):                  0.500   Jarque-Bera (JB):                0.860
# Skew:                          -0.104   Prob(JB):                        0.650
# Kurtosis:                       3.404   Cond. No.                         32.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
''' 
Căn cứ vào điểm số T5 sẽ giải thích được 60% sự thay đổi của T6 (Adj. R-squared) 
Prob (F-statistic) < 0.05: cho biết mô hình có khả năng phù hợp cho tổng thể [nó là p
value] 
const (2,11) chính là A0 
x1 là A1 
=> T6 = 2.113 + 0.7182 * T5 
P>|t| = 0.000 rất nhỏ < 5% => x1 tương ứng với T5 (x` = T5) => biến T5 có ý nghĩa 
thống kê trong phương trình này hay nói T5 có  
ý nghĩa tham gia đánh giá tác động tới biến T6 
''' 
''' 
Bước 5: Giả sử T5 = 7.5, dự báo T6 = 7.499 
''' 
# Khám phá sự ảnh hưởng của T6 đến điểm thi LOGIC 
# adding a constant 
X_with_constant = sm.add_constant(df[["T6"]].values) 
y = df[['TOANLOGICPHANTICH']].values 
# performing the regression 
result = sm.OLS(y,X_with_constant).fit() 
# Result of statsmodels 
print(result.summary()) 
''' 
Adj. R-squared = 8%: quá ít, không thể giải thích cho điểm LOGIC, nói cách khác k dựa 
T6 để gthich dc 
Prob (F-statistic) = 0.00230 => phù hợp, bé hơn 0.05, có ý nghĩa thống kê 
LOGIC = 2.6287 + 0.2344 * T6  
P>|t| = 0.000 < 0.05: T6 có ý nghĩa thống kê
Giả sử T6 = 7.0 
=> LOGIC = 4.2695 
'''
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     9.798
# Date:                Mon, 07 Oct 2024   Prob (F-statistic):            0.00230
# Time:                        00:58:08   Log-Likelihood:                -142.46
# No. Observations:                 100   AIC:                             288.9
# Df Residuals:                      98   BIC:                             294.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.6287      0.529      4.965      0.000       1.578       3.679
# x1             0.2344      0.075      3.130      0.002       0.086       0.383
# ==============================================================================
# Omnibus:                       12.364   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               14.780
# Skew:                           0.671   Prob(JB):                     0.000617
# Kurtosis:                       4.322   Cond. No.                         37.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ' \nAdj. R-squared = 8%: quá ít, không thể giải thích cho điểm LOGIC, nói cách khác k dựa \nT6 để gthich dc \nProb (F-statistic) = 0.00230 => phù hợp, bé hơn 0.05, có ý nghĩa thống kê \nLOGIC = 2.6287 + 0.2344 * T6  \nP>|t| = 0.000 < 0.05: T6 có ý nghĩa thống kê\nGiả sử T6 = 7.0 \n=> LOGIC = 4.2695 \n'

# %%
# Khám phá sự ảnh hưởng của T6 đến điểm thi LOGIC 
# adding a constant 
X_with_constant = sm.add_constant(df[["T6"]].values) 
y = df[['TOANLOGICPHANTICH']].values 
# performing the regression 
result = sm.OLS(y,X_with_constant).fit() 
# Result of statsmodels 
print(result.summary()) 
''' 
Adj. R-squared = 8%: quá ít, không thể giải thích cho điểm LOGIC, nói cách khác k dựa 
T6 để gthich dc 
Prob (F-statistic) = 0.00230 => phù hợp, bé hơn 0.05, có ý nghĩa thống kê 
LOGIC = 2.6287 + 0.2344 * T6  
P>|t| = 0.000 < 0.05: T6 có ý nghĩa thống kê 
Giả sử T6 = 7.0 
=> LOGIC = 4.2695 
'''
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     9.798
# Date:                Mon, 07 Oct 2024   Prob (F-statistic):            0.00230
# Time:                        00:58:45   Log-Likelihood:                -142.46
# No. Observations:                 100   AIC:                             288.9
# Df Residuals:                      98   BIC:                             294.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.6287      0.529      4.965      0.000       1.578       3.679
# x1             0.2344      0.075      3.130      0.002       0.086       0.383
# ==============================================================================
# Omnibus:                       12.364   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               14.780
# Skew:                           0.671   Prob(JB):                     0.000617
# Kurtosis:                       4.322   Cond. No.                         37.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ' \nAdj. R-squared = 8%: quá ít, không thể giải thích cho điểm LOGIC, nói cách khác k dựa \nT6 để gthich dc \nProb (F-statistic) = 0.00230 => phù hợp, bé hơn 0.05, có ý nghĩa thống kê \nLOGIC = 2.6287 + 0.2344 * T6  \nP>|t| = 0.000 < 0.05: T6 có ý nghĩa thống kê \nGiả sử T6 = 7.0 \n=> LOGIC = 4.2695 \n'

# %%
X_with_constant = sm.add_constant(df[["T5","T6"]].values) 
y = df[['TOANLOGICPHANTICH']].values 
# performing the regression 
result = sm.OLS(y,X_with_constant).fit() 
# Result of statsmodels 
print(result.summary()) 
''' 
1. Độc lập T5,T6 
phụ thuộc Logic 
2. Logic f(T5,T6) 
Logic = A0 + A1*T5 + A2*T6 * epsilon = 2.7072 - 0.0913*T5 + 0.3115 * T6 + epsilon 
'''
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.079
# Method:                 Least Squares   F-statistic:                     5.226
# Date:                Mon, 07 Oct 2024   Prob (F-statistic):            0.00699
# Time:                        00:58:50   Log-Likelihood:                -142.11
# No. Observations:                 100   AIC:                             290.2
# Df Residuals:                      97   BIC:                             298.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.7072      0.539      5.026      0.000       1.638       3.776
# x1            -0.0913      0.110     -0.828      0.410      -0.310       0.128
# x2             0.3115      0.120      2.606      0.011       0.074       0.549
# ==============================================================================
# Omnibus:                       14.098   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               17.272
# Skew:                           0.745   Prob(JB):                     0.000178
# Kurtosis:                       4.387   Cond. No.                         52.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ' \n1. Độc lập T5,T6 \nphụ thuộc Logic \n2. Logic f(T5,T6) \nLogic = A0 + A1*T5 + A2*T6 * epsilon = 2.7072 - 0.0913*T5 + 0.3115 * T6 + epsilon \n'

# %%
df = df[['T5','T6','GT','DT','KV','KT','NGONNGU','TOANLOGICPHANTICH','GIAIQUYETVANDE','NGAYTHI','DINHHUONGNGHENGHIEP']] 
df.rename(columns={'TOANLOGICPHANTICH':'LOGIC', 
                  'GIAIQUYETVANDE':'UNGXU', 
                  'DINHHUONGNGHENGHIEP':'HUONGNGHIEP'},inplace=True)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2660\4133677683.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'TOANLOGICPHANTICH':'LOGIC',

# %%
# Hãy phân tích sự ảnh hưởng của điểm toán học kì 1,2 năm lớp 12 đến điểm NGONNGU 
X_with_constant = sm.add_constant(df[["T5","T6"]].values) 
y = df[['NGONNGU']].values 
# performing the regression 
result = sm.OLS(y,X_with_constant).fit() 
# Result of statsmodels 
print(result.summary()) 
''' 
Adj. R-squared = 1% : quá ít, k gthich dc gì  
Prob (F-statistic): 7%  
'''
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.3109
# Date:                Mon, 07 Oct 2024   Prob (F-statistic):              0.734
# Time:                        00:59:36   Log-Likelihood:                -176.45
# No. Observations:                 100   AIC:                             358.9
# Df Residuals:                      97   BIC:                             366.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.8860      0.759      5.117      0.000       2.379       5.393
# x1             0.1114      0.155      0.716      0.475      -0.197       0.420
# x2            -0.1289      0.169     -0.765      0.446      -0.463       0.206
# ==============================================================================
# Omnibus:                        3.571   Durbin-Watson:                   1.774
# Prob(Omnibus):                  0.168   Jarque-Bera (JB):                2.978
# Skew:                           0.314   Prob(JB):                        0.226
# Kurtosis:                       2.433   Cond. No.                         52.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ' \nAdj. R-squared = 1% : quá ít, k gthich dc gì  \nProb (F-statistic): 7%  \n'

# %%
# Đánh giá mức độ tác động giữa các yếu tố đến 1 đối tượng bằng phân tích hồi quy 
# tuyến tính 
# Hãy cho biết mức độ tác động của T5, T6 (độc lập) đến điểm LOGIC (phụ thuộc) 
# adding a constant 
X = df[["T5","T6"]].values 
y = df[['LOGIC']].values 
# performing the regresssion 
result = sm.OLS(y,X).fit() 
# result of statsmodels 
print(result.summary()) 
''' 
x2 = |0.5934| => T6 tác động mạnh hơn so với T5 (x1 = |0.0063|) 
vì x2 dương nên tác động tích cực, còn âm mới tác động tiêu cực (nghịch biến) 
''' 
# Đánh giá mức độ tác động giữa các yếu tố đến 1 đối tượng bằng phân tích hồi quy 
# tuyến tính
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.934
# Model:                            OLS   Adj. R-squared (uncentered):              0.933
# Method:                 Least Squares   F-statistic:                              694.9
# Date:                Mon, 07 Oct 2024   Prob (F-statistic):                    1.30e-58
# Time:                        00:59:49   Log-Likelihood:                         -153.68
# No. Observations:                 100   AIC:                                      311.4
# Df Residuals:                      98   BIC:                                      316.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.0063      0.121      0.052      0.959      -0.234       0.247
# x2             0.5934      0.118      5.031      0.000       0.359       0.827
# ==============================================================================
# Omnibus:                        9.328   Durbin-Watson:                   1.966
# Prob(Omnibus):                  0.009   Jarque-Bera (JB):                9.293
# Skew:                           0.636   Prob(JB):                      0.00960
# Kurtosis:                       3.783   Cond. No.                         14.6
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ' \nx2 = |0.5934| => T6 tác động mạnh hơn so với T5 (x1 = |0.0063|) \nvì x2 dương nên tác động tích cực, còn âm mới tác động tiêu cực (nghịch biến) \n'

# %%
# Hãy cho biết mức độ tác động của T5, T6 đến điểm UNGXU 
# adding a constant 
X = df[["T5","T6"]].values 
y = df[['UNGXU']].values 
# performing the regresssion 
result = sm.OLS(y,X).fit() 
# result of statsmodels 
print(result.summary()) 
''' 
x2 = |0.5318| => T6 tác động mạnh hơn so với T5 (x1 = |0.1519|) 
vì x2 dương nên tác động tích cực (đồng biến), còn âm mới tác động tiêu cực (nghịch 
biến) 
'''
# Out:
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                      y   R-squared (uncentered):                   0.926
# Model:                            OLS   Adj. R-squared (uncentered):              0.924
# Method:                 Least Squares   F-statistic:                              612.1
# Date:                Mon, 07 Oct 2024   Prob (F-statistic):                    4.24e-56
# Time:                        01:00:00   Log-Likelihood:                         -172.41
# No. Observations:                 100   AIC:                                      348.8
# Df Residuals:                      98   BIC:                                      354.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# x1             0.1519      0.146      1.039      0.301      -0.138       0.442
# x2             0.5318      0.142      3.738      0.000       0.249       0.814
# ==============================================================================
# Omnibus:                        0.142   Durbin-Watson:                   1.874
# Prob(Omnibus):                  0.931   Jarque-Bera (JB):                0.323
# Skew:                          -0.025   Prob(JB):                        0.851
# Kurtosis:                       2.726   Cond. No.                         14.6
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ' \nx2 = |0.5318| => T6 tác động mạnh hơn so với T5 (x1 = |0.1519|) \nvì x2 dương nên tác động tích cực (đồng biến), còn âm mới tác động tiêu cực (nghịch \nbiến) \n'

# %%
# Cho biet su anh huong cua diem toan hk1 12 la T5, diem toan HK2 12 la T6 (cai nao la bien phu thuoc, cai nao la biet doc lap)
# Bien phu thuoc: T6, Bien doc lap: T5
import statsmodels.api as sm
x = sm.add_constant(df[['T5']].values)
y = df['T6'].values
model = sm.OLS(y, x).fit()
print(model.summary())
# 2 bien co phu thuoc vao nhau khong
# Co phu thuoc
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.606
# Model:                            OLS   Adj. R-squared:                  0.602
# Method:                 Least Squares   F-statistic:                     151.0
# Date:                Thu, 26 Sep 2024   Prob (F-statistic):           1.48e-21
# Time:                        13:48:03   Log-Likelihood:                -125.76
# No. Observations:                 100   AIC:                             255.5
# Df Residuals:                      98   BIC:                             260.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.1130      0.402      5.257      0.000       1.315       2.911
# x1             0.7182      0.058     12.286      0.000       0.602       0.834
# ==============================================================================
# Omnibus:                        1.387   Durbin-Watson:                   1.738
# Prob(Omnibus):                  0.500   Jarque-Bera (JB):                0.860
# Skew:                          -0.104   Prob(JB):                        0.650
# Kurtosis:                       3.404   Cond. No.                         32.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Viet phuong trinh hoi quy 
# T6 = 2.1130 +  0.7182*T5

# %%
# cho biet diem T6 co anh huong toi diem Logic khong?
# bien doc lap la T6, bien phu thuoc la TOANLOGICPHANTICH
x = sm.add_constant(df[['T6']].values)
y = df['TOANLOGICPHANTICH'].values
model = sm.OLS(y, x).fit()
print(model.summary())
# Viet phuong trinh hoi quy
# TOANLOGICPHANTICH = 2.6287 +  0.2344*T6
# logic khong phu thuoc vao T6
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.091
# Model:                            OLS   Adj. R-squared:                  0.082
# Method:                 Least Squares   F-statistic:                     9.798
# Date:                Thu, 26 Sep 2024   Prob (F-statistic):            0.00230
# Time:                        13:48:06   Log-Likelihood:                -142.46
# No. Observations:                 100   AIC:                             288.9
# Df Residuals:                      98   BIC:                             294.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.6287      0.529      4.965      0.000       1.578       3.679
# x1             0.2344      0.075      3.130      0.002       0.086       0.383
# ==============================================================================
# Omnibus:                       12.364   Durbin-Watson:                   1.974
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               14.780
# Skew:                           0.671   Prob(JB):                     0.000617
# Kurtosis:                       4.322   Cond. No.                         37.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Su anh huong cua T5 va T6 co anh huong den diemtoanlogic khong
# T5 va T6 phu thuoc vao TOANLOGICPHANTICH
x = sm.add_constant(df[['T5', 'T6']].values)
y = df['TOANLOGICPHANTICH'].values
model = sm.OLS(y, x).fit()
print(model.summary())
# Viet phuong trinh hoi quy
# TOANLOGICPHANTICH = 2.7072 - 0.0913*T5 +  0.3115*T6
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.079
# Method:                 Least Squares   F-statistic:                     5.226
# Date:                Thu, 26 Sep 2024   Prob (F-statistic):            0.00699
# Time:                        13:48:08   Log-Likelihood:                -142.11
# No. Observations:                 100   AIC:                             290.2
# Df Residuals:                      97   BIC:                             298.0
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.7072      0.539      5.026      0.000       1.638       3.776
# x1            -0.0913      0.110     -0.828      0.410      -0.310       0.128
# x2             0.3115      0.120      2.606      0.011       0.074       0.549
# ==============================================================================
# Omnibus:                       14.098   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               17.272
# Skew:                           0.745   Prob(JB):                     0.000178
# Kurtosis:                       4.387   Cond. No.                         52.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# Diem GIAIQUYETVANDE va diem diem TOANLOGICPHANTICH co anh huong den nhau khong
#Bien phu thuoc: TOANLOGICPHANTICH, Bien doc lap: GIAIQUYETVANDE
x = sm.add_constant(df[['GIAIQUYETVANDE']].values)
y = df['TOANLOGICPHANTICH'].values
model = sm.OLS(y, x).fit()
print(model.summary())
# Viet phuong trinh hoi quy
# TOANLOGICPHANTICH =  4.7093 - 0.0932*GIAIQUYETVANDE
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.8278
# Date:                Thu, 26 Sep 2024   Prob (F-statistic):              0.365
# Time:                        13:48:11   Log-Likelihood:                -146.80
# No. Observations:                 100   AIC:                             297.6
# Df Residuals:                      98   BIC:                             302.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          4.7093      0.510      9.226      0.000       3.696       5.722
# x1            -0.0932      0.102     -0.910      0.365      -0.296       0.110
# ==============================================================================
# Omnibus:                        8.467   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):                9.528
# Skew:                           0.490   Prob(JB):                      0.00853
# Kurtosis:                       4.152   Cond. No.                         24.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
# SU anh huong cua T5 va T6 co lien quan den NGONNGU khong
# Bien phu thuoc: NGONNGU, Bien doc lap: T5, T6
x = sm.add_constant(df[['T5', 'T6']].values)
y = df['NGONNGU'].values
model = sm.OLS(y, x).fit()
print(model.summary())
# Viet phuong trinh hoi quy
# NGONNGU =  3.8860 + 0.1114*T5 - 0.1289*T6
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.3109
# Date:                Thu, 26 Sep 2024   Prob (F-statistic):              0.734
# Time:                        13:48:14   Log-Likelihood:                -176.45
# No. Observations:                 100   AIC:                             358.9
# Df Residuals:                      97   BIC:                             366.7
# Df Model:                           2
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.8860      0.759      5.117      0.000       2.379       5.393
# x1             0.1114      0.155      0.716      0.475      -0.197       0.420
# x2            -0.1289      0.169     -0.765      0.446      -0.463       0.206
# ==============================================================================
# Omnibus:                        3.571   Durbin-Watson:                   1.774
# Prob(Omnibus):                  0.168   Jarque-Bera (JB):                2.978
# Skew:                           0.314   Prob(JB):                        0.226
# Kurtosis:                       2.433   Cond. No.                         52.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
